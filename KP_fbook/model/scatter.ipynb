# %%
import pandas as pd
import matplotlib.pyplot as plt

import argparse


    df = pd.read_csv("results/tr_all_results.csv")
    output = args.label

    ax1 = df.reset_index().plot(kind='scatter', x='index', y='nawl_recall')
